# %%
import numpy as np
import pandas as pd
import requests
import json

# %%
response = requests.get('https://api.rawg.io/api/games?dates=2000-01-01,2021-12-31&ordering=-rating')

# %%
# create a variable for json file
rating_data = response.json()

# %%
# check json data
rating_data
# Out:
# {'count': 438710,
#  'next': 'https://api.rawg.io/api/games?dates=2000-01-01%2C2021-12-31&ordering=-rating&page=2',
#  'previous': None,
#  'results': [{'slug': 'the-world-ends-with-you-solo-remix-for-ipad',
#    'name': 'The World Ends with You: Solo Remix',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 3, 'name': 'iOS', 'slug': 'ios'}}],
#    'stores': [{'store': {'id': 4,
#       'name': 'App Store',
#       'slug': 'apple-appstore'}}],
#    'released': '2012-08-27',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/ebb/ebb68b67bb3c0fbd7f67b3ac56f9d24b.jpg',
#    'rating': 4.86,
#    'rating_top': 5,
#    'ratings': [{'id': 5, 'title': 'exceptional', 'count': 6, 'percent': 85.71},
#     {'id': 4, 'title': 'recommended', 'count': 1, 'percent': 14.29}],
#    'ratings_count': 7,
#    'reviews_text_count': 0,
#    'added': 12,
#    'added_by_status': {'yet': 2,
#     'owned': 3,
#     'beaten': 3,
#     'toplay': 3,
#     'dropped': 1},
#    'metacritic': None,
#    'suggestions_count': 245,
#    'id': 132,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 117,
#      'name': 'Mystery',
#      'slug': 'mystery',
#      'language': 'eng',
#      'games_count': 5645,
#      'image_background': 'https://media.rawg.io/media/games/813/813f9dab418a3d549f8b9ad8ef2f3d9c.jpg'},
#     {'id': 24,
#      'name': 'RPG',
#      'slug': 'rpg',
#      'language': 'eng',
#      'games_count': 10453,
#      'image_background': 'https://media.rawg.io/media/games/c6b/c6bfece1daf8d06bc0a60632ac78e5bf.jpg'},
#     {'id': 295,
#      'name': 'Soundtrack',
#      'slug': 'soundtrack',
#      'language': 'eng',
#      'games_count': 1899,
#      'image_background': 'https://media.rawg.io/media/screenshots/5ce/5ce17393fdcd1a4356187e388fa21723.jpeg'},
#     {'id': 406,
#      'name': 'Story',
#      'slug': 'story',
#      'language': 'eng',
#      'games_count': 7485,
#      'image_background': 'https://media.rawg.io/media/screenshots/7f8/7f8b58994fc420fefaa5fb9992335a11.jpg'},
#     {'id': 604,
#      'name': 'simple',
#      'slug': 'simple',
#      'language': 'eng',
#      'games_count': 5292,
#      'image_background': 'https://media.rawg.io/media/screenshots/343/343ba814ff5e9bae8f67e7db4844f46d.jpg'},
#     {'id': 981,
#      'name': 'battle',
#      'slug': 'battle',
#      'language': 'eng',
#      'games_count': 8164,
#      'image_background': 'https://media.rawg.io/media/games/cd2/cd2a1a360839002bceadc5a8b3c7dbf7.jpg'},
#     {'id': 974,
#      'name': 'death',
#      'slug': 'death',
#      'language': 'eng',
#      'games_count': 2509,
#      'image_background': 'https://media.rawg.io/media/screenshots/548/5480f9bb1204045c5164d3f1293c9f41.jpg'},
#     {'id': 1129,
#      'name': 'art',
#      'slug': 'art',
#      'language': 'eng',
#      'games_count': 5503,
#      'image_background': 'https://media.rawg.io/media/screenshots/741/741bcfe15b1fe83ddc54be4f78749cc3.jpg'},
#     {'id': 1465,
#      'name': 'combat',
#      'slug': 'combat',
#      'language': 'eng',
#      'games_count': 3928,
#      'image_background': 'https://media.rawg.io/media/games/260/26023c855f1769a93411d6a7ea084632.jpeg'},
#     {'id': 1530,
#      'name': 'animation',
#      'slug': 'animation',
#      'language': 'eng',
#      'games_count': 2057,
#      'image_background': 'https://media.rawg.io/media/screenshots/9bf/9bf17af55dba0e49bb9259f62dafd6bc.jpg'},
#     {'id': 1724,
#      'name': 'Superpowers',
#      'slug': 'superpowers',
#      'language': 'eng',
#      'games_count': 322,
#      'image_background': 'https://media.rawg.io/media/screenshots/b3c/b3c672e0d9094baf91ef619002bbe82b.jpg'},
#     {'id': 1986,
#      'name': 'ice',
#      'slug': 'ice',
#      'language': 'eng',
#      'games_count': 1716,
#      'image_background': 'https://media.rawg.io/media/games/773/7731c87e1b3350634b1924a46f2da282.png'}],
#    'user_game': None,
#    'reviews_count': 7,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/ebb/ebb68b67bb3c0fbd7f67b3ac56f9d24b.jpg'},
#     {'id': 2039382,
#      'image': 'https://media.rawg.io/media/screenshots/323/3230d5c737b4378222b8b1d7388957e5.jpg'},
#     {'id': 2039383,
#      'image': 'https://media.rawg.io/media/screenshots/c69/c69a7b875d079473dcab1af6b03461bd.jpg'},
#     {'id': 2039384,
#      'image': 'https://media.rawg.io/media/screenshots/b3b/b3bdf18ce325a1ba7e7173abc8ac5b8b.jpg'},
#     {'id': 2039385,
#      'image': 'https://media.rawg.io/media/screenshots/980/9803e97dc9167666e781508137865232.jpg'},
#     {'id': 2039386,
#      'image': 'https://media.rawg.io/media/screenshots/3d3/3d350e051ece0015344dc779073ecc4f.jpg'},
#     {'id': 970,
#      'image': 'https://media.rawg.io/media/screenshots/047/047837d9aea61bca11fd389c9f85cd40.jpeg'}],
#    'parent_platforms': [{'platform': {'id': 4, 'name': 'iOS', 'slug': 'ios'}}],
#    'genres': [{'id': 4, 'name': 'Action', 'slug': 'action'},
#     {'id': 5, 'name': 'RPG', 'slug': 'role-playing-games-rpg'}]},
#   {'slug': 'astro-boy-omega-factor',
#    'name': 'Astro Boy: Omega Factor',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 24,
#       'name': 'Game Boy Advance',
#       'slug': 'game-boy-advance'}}],
#    'stores': None,
#    'released': '2003-12-18',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/cda/cda8d4dbee864ef1578a698d6f0507ad.jpg',
#    'rating': 4.83,
#    'rating_top': 5,
#    'ratings': [{'id': 5, 'title': 'exceptional', 'count': 5, 'percent': 83.33},
#     {'id': 4, 'title': 'recommended', 'count': 1, 'percent': 16.67}],
#    'ratings_count': 6,
#    'reviews_text_count': 0,
#    'added': 20,
#    'added_by_status': {'yet': 3,
#     'owned': 5,
#     'beaten': 5,
#     'toplay': 5,
#     'dropped': 1,
#     'playing': 1},
#    'metacritic': None,
#    'suggestions_count': 227,
#    'id': 53135,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 31,
#      'name': 'Singleplayer',
#      'slug': 'singleplayer',
#      'language': 'eng',
#      'games_count': 86169,
#      'image_background': 'https://media.rawg.io/media/games/b7b/b7b8381707152afc7d91f5d95de70e39.jpg'},
#     {'id': 37796,
#      'name': 'exclusive',
#      'slug': 'exclusive',
#      'language': 'eng',
#      'games_count': 4453,
#      'image_background': 'https://media.rawg.io/media/games/363/36306deef81e7955a5d0f5c3b43fccee.jpg'},
#     {'id': 37797,
#      'name': 'true exclusive',
#      'slug': 'true-exclusive',
#      'language': 'eng',
#      'games_count': 3981,
#      'image_background': 'https://media.rawg.io/media/games/1de/1deed95a21d854f8a5cdfc249ff54c6c.jpg'}],
#    'user_game': None,
#    'reviews_count': 6,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/cda/cda8d4dbee864ef1578a698d6f0507ad.jpg'},
#     {'id': 730856,
#      'image': 'https://media.rawg.io/media/screenshots/a9d/a9d70487089f573eff61326eaaa40a8e.jpg'},
#     {'id': 730857,
#      'image': 'https://media.rawg.io/media/screenshots/5ab/5ab81907107ec7f46c29ed4f20bd74b5.jpg'},
#     {'id': 730858,
#      'image': 'https://media.rawg.io/media/screenshots/90f/90ffde10435fe53fd1f0247e8b0fb408.jpg'},
#     {'id': 730859,
#      'image': 'https://media.rawg.io/media/screenshots/0ea/0ea072fe1830721c4807fa8285745bb0.jpg'},
#     {'id': 730860,
#      'image': 'https://media.rawg.io/media/screenshots/1eb/1eb1a26ecf39312c3420ff2b99d367b4.jpg'},
#     {'id': 730861,
#      'image': 'https://media.rawg.io/media/screenshots/557/5577b5e7d1bc6a2856f746e76234bc76.jpg'}],
#    'parent_platforms': [{'platform': {'id': 7,
#       'name': 'Nintendo',
#       'slug': 'nintendo'}}],
#    'genres': []},
#   {'slug': 'kara-no-shojo',
#    'name': 'Kara no Shojo',
#    'playtime': 8,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}}],
#    'stores': [{'store': {'id': 1, 'name': 'Steam', 'slug': 'steam'}}],
#    'released': '2018-10-22',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/3d2/3d248a9fa79cd570a9cc40f250175a9e.jpg',
#    'rating': 4.83,
#    'rating_top': 5,
#    'ratings': [{'id': 5, 'title': 'exceptional', 'count': 5, 'percent': 83.33},
#     {'id': 4, 'title': 'recommended', 'count': 1, 'percent': 16.67}],
#    'ratings_count': 6,
#    'reviews_text_count': 0,
#    'added': 29,
#    'added_by_status': {'yet': 4, 'owned': 17, 'beaten': 7, 'toplay': 1},
#    'metacritic': None,
#    'suggestions_count': 271,
#    'id': 257281,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 134,
#      'name': 'Anime',
#      'slug': 'anime',
#      'language': 'eng',
#      'games_count': 4979,
#      'image_background': 'https://media.rawg.io/media/screenshots/6d3/6d367773c06886535620f2d7fb1cb866.jpg'},
#     {'id': 40849,
#      'name': 'Steam Cloud',
#      'slug': 'steam-cloud',
#      'language': 'eng',
#      'games_count': 9280,
#      'image_background': 'https://media.rawg.io/media/games/f99/f9979698c43fd84c3ab69280576dd3af.jpg'},
#     {'id': 142,
#      'name': 'Detective',
#      'slug': 'detective',
#      'language': 'eng',
#      'games_count': 1188,
#      'image_background': 'https://media.rawg.io/media/games/cee/cee577e2097a59b77193fe2bce94667d.jpg'},
#     {'id': 26,
#      'name': 'Gore',
#      'slug': 'gore',
#      'language': 'eng',
#      'games_count': 3449,
#      'image_background': 'https://media.rawg.io/media/games/dbe/dbeeb30e02b59f55c4d8cf4f103a83b9.jpg'},
#     {'id': 42,
#      'name': 'Great Soundtrack',
#      'slug': 'great-soundtrack',
#      'language': 'eng',
#      'games_count': 3087,
#      'image_background': 'https://media.rawg.io/media/games/ee3/ee3e10193aafc3230ba1cae426967d10.jpg'},
#     {'id': 16,
#      'name': 'Horror',
#      'slug': 'horror',
#      'language': 'eng',
#      'games_count': 17393,
#      'image_background': 'https://media.rawg.io/media/games/dd5/dd50d4266915d56dd5b63ae1bf72606a.jpg'},
#     {'id': 192,
#      'name': 'Mature',
#      'slug': 'mature',
#      'language': 'eng',
#      'games_count': 724,
#      'image_background': 'https://media.rawg.io/media/games/a34/a348e613424260bc7e034fb6031c762e.jpg'},
#     {'id': 218,
#      'name': 'Multiple Endings',
#      'slug': 'multiple-endings',
#      'language': 'eng',
#      'games_count': 2523,
#      'image_background': 'https://media.rawg.io/media/games/e72/e7259ec544cad1c3bac229fa0de46040.jpg'},
#     {'id': 117,
#      'name': 'Mystery',
#      'slug': 'mystery',
#      'language': 'eng',
#      'games_count': 5753,
#      'image_background': 'https://media.rawg.io/media/games/562/562553814dd54e001a541e4ee83a591c.jpg'},
#     {'id': 312,
#      'name': 'NSFW',
#      'slug': 'nsfw',
#      'language': 'eng',
#      'games_count': 431,
#      'image_background': 'https://media.rawg.io/media/screenshots/2a8/2a88268867c42952c55382bb629c456d.jpg'},
#     {'id': 44,
#      'name': 'Nudity',
#      'slug': 'nudity',
#      'language': 'eng',
#      'games_count': 2177,
#      'image_background': 'https://media.rawg.io/media/games/16b/16b1b7b36e2042d1128d5a3e852b3b2f.jpg'},
#     {'id': 50,
#      'name': 'Sexual Content',
#      'slug': 'sexual-content',
#      'language': 'eng',
#      'games_count': 1766,
#      'image_background': 'https://media.rawg.io/media/games/26d/26d4437715bee60138dab4a7c8c59c92.jpg'},
#     {'id': 31,
#      'name': 'Singleplayer',
#      'slug': 'singleplayer',
#      'language': 'eng',
#      'games_count': 92374,
#      'image_background': 'https://media.rawg.io/media/games/7fa/7fa0b586293c5861ee32490e953a4996.jpg'},
#     {'id': 118,
#      'name': 'Story Rich',
#      'slug': 'story-rich',
#      'language': 'eng',
#      'games_count': 7867,
#      'image_background': 'https://media.rawg.io/media/games/120/1201a40e4364557b124392ee50317b99.jpg'},
#     {'id': 34,
#      'name': 'Violent',
#      'slug': 'violent',
#      'language': 'eng',
#      'games_count': 4046,
#      'image_background': 'https://media.rawg.io/media/games/5a4/5a44112251d70a25291cc33757220fce.jpg'},
#     {'id': 90,
#      'name': 'Visual Novel',
#      'slug': 'visual-novel',
#      'language': 'eng',
#      'games_count': 1630,
#      'image_background': 'https://media.rawg.io/media/games/8d6/8d69eb6c32ed6acfd75f82d532144993.jpg'}],
#    'user_game': None,
#    'reviews_count': 6,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/3d2/3d248a9fa79cd570a9cc40f250175a9e.jpg'},
#     {'id': 1698119,
#      'image': 'https://media.rawg.io/media/screenshots/551/551742f83ef97341bac1356cd76dec3e.jpg'},
#     {'id': 1698120,
#      'image': 'https://media.rawg.io/media/screenshots/cd5/cd5627ad761ef6970ac948002588c8c3.jpg'},
#     {'id': 1698121,
#      'image': 'https://media.rawg.io/media/screenshots/262/262da3710e5205823497ab4bd9731eae.jpg'},
#     {'id': 1698122,
#      'image': 'https://media.rawg.io/media/screenshots/a29/a29f132d313fb2bc5e3eca53cdef249d.jpg'},
#     {'id': 1698123,
#      'image': 'https://media.rawg.io/media/screenshots/92b/92bcfd08cc74c9d4f3d8765aebc77c57.jpg'},
#     {'id': 1698124,
#      'image': 'https://media.rawg.io/media/screenshots/602/6025fdff67ff32116f09598b20378385.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}}],
#    'genres': [{'id': 3, 'name': 'Adventure', 'slug': 'adventure'}]},
#   {'slug': 'persona-5-royal',
#    'name': 'Persona 5 Royal',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 18,
#       'name': 'PlayStation 4',
#       'slug': 'playstation4'}}],
#    'stores': [{'store': {'id': 3,
#       'name': 'PlayStation Store',
#       'slug': 'playstation-store'}}],
#    'released': '2020-03-31',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/games/a9c/a9c789951de65da545d51f664b4f2ce0.jpg',
#    'rating': 4.81,
#    'rating_top': 5,
#    'ratings': [{'id': 5,
#      'title': 'exceptional',
#      'count': 103,
#      'percent': 91.15},
#     {'id': 4, 'title': 'recommended', 'count': 4, 'percent': 3.54},
#     {'id': 3, 'title': 'meh', 'count': 3, 'percent': 2.65},
#     {'id': 1, 'title': 'skip', 'count': 3, 'percent': 2.65}],
#    'ratings_count': 108,
#    'reviews_text_count': 5,
#    'added': 878,
#    'added_by_status': {'yet': 47,
#     'owned': 421,
#     'beaten': 78,
#     'toplay': 249,
#     'dropped': 8,
#     'playing': 75},
#    'metacritic': 95,
#    'suggestions_count': 273,
#    'id': 339958,
#    'score': None,
#    'clip': {'clip': 'https://media.rawg.io/media/stories-640/341/341484e0768b5e206e6f264a2091c536.mp4',
#     'clips': {'320': 'https://media.rawg.io/media/stories-320/809/8091ae98a2bb06d6e3ed5a25392f03f6.mp4',
#      '640': 'https://media.rawg.io/media/stories-640/341/341484e0768b5e206e6f264a2091c536.mp4',
#      'full': 'https://media.rawg.io/media/stories/af8/af80d96153fe6ac689916b14dd3fc2f4.mp4'},
#     'video': 'DPCLSkZmpLQ',
#     'preview': 'https://media.rawg.io/media/stories-previews/886/886bedd0507e010522c23bd3372b6c0b.jpg'},
#    'tags': [],
#    'user_game': None,
#    'reviews_count': 113,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/games/a9c/a9c789951de65da545d51f664b4f2ce0.jpg'},
#     {'id': 1988952,
#      'image': 'https://media.rawg.io/media/screenshots/e70/e701311c431504ccd8653a5243188a13.jpg'},
#     {'id': 1988953,
#      'image': 'https://media.rawg.io/media/screenshots/5af/5af7efeca549b9a768870c52eff7e128.jpg'},
#     {'id': 2186917,
#      'image': 'https://media.rawg.io/media/screenshots/fff/fff1f025d1390753810154b7a40f5bad.jpg'},
#     {'id': 2186918,
#      'image': 'https://media.rawg.io/media/screenshots/36d/36dac15fbe4556d5ae062ff102ce3461.jpg'},
#     {'id': 2186919,
#      'image': 'https://media.rawg.io/media/screenshots/b26/b2604ecc559bccfb72dca2c869f53b63.jpg'}],
#    'parent_platforms': [{'platform': {'id': 2,
#       'name': 'PlayStation',
#       'slug': 'playstation'}}],
#    'genres': [{'id': 3, 'name': 'Adventure', 'slug': 'adventure'},
#     {'id': 5, 'name': 'RPG', 'slug': 'role-playing-games-rpg'}]},
#   {'slug': 'shovel-knight-shovel-of-hope',
#    'name': 'Shovel Knight: Shovel of Hope',
#    'playtime': 2,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 18, 'name': 'PlayStation 4', 'slug': 'playstation4'}},
#     {'platform': {'id': 1, 'name': 'Xbox One', 'slug': 'xbox-one'}},
#     {'platform': {'id': 7,
#       'name': 'Nintendo Switch',
#       'slug': 'nintendo-switch'}},
#     {'platform': {'id': 8, 'name': 'Nintendo 3DS', 'slug': 'nintendo-3ds'}},
#     {'platform': {'id': 5, 'name': 'macOS', 'slug': 'macos'}},
#     {'platform': {'id': 6, 'name': 'Linux', 'slug': 'linux'}},
#     {'platform': {'id': 16, 'name': 'PlayStation 3', 'slug': 'playstation3'}},
#     {'platform': {'id': 19, 'name': 'PS Vita', 'slug': 'ps-vita'}},
#     {'platform': {'id': 10, 'name': 'Wii U', 'slug': 'wii-u'}}],
#    'stores': [{'store': {'id': 1, 'name': 'Steam', 'slug': 'steam'}},
#     {'store': {'id': 5, 'name': 'GOG', 'slug': 'gog'}}],
#    'released': '2014-06-26',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/32e/32e2fca8b56687dd33ae966093012671.jpg',
#    'rating': 4.78,
#    'rating_top': 5,
#    'ratings': [{'id': 5, 'title': 'exceptional', 'count': 7, 'percent': 77.78},
#     {'id': 4, 'title': 'recommended', 'count': 2, 'percent': 22.22}],
#    'ratings_count': 9,
#    'reviews_text_count': 0,
#    'added': 24,
#    'added_by_status': {'yet': 1, 'owned': 8, 'beaten': 9, 'toplay': 6},
#    'metacritic': None,
#    'suggestions_count': 286,
#    'id': 392459,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 40836,
#      'name': 'Full controller support',
#      'slug': 'full-controller-support',
#      'language': 'eng',
#      'games_count': 9349,
#      'image_background': 'https://media.rawg.io/media/games/ed5/ed5b7d01dd68fd8d598c91ad61f153af.jpg'},
#     {'id': 40847,
#      'name': 'Steam Achievements',
#      'slug': 'steam-achievements',
#      'language': 'eng',
#      'games_count': 19823,
#      'image_background': 'https://media.rawg.io/media/games/91c/91c4f377c1e09755b60a0102c5252843.jpg'},
#     {'id': 40849,
#      'name': 'Steam Cloud',
#      'slug': 'steam-cloud',
#      'language': 'eng',
#      'games_count': 9259,
#      'image_background': 'https://media.rawg.io/media/games/b45/b45575f34285f2c4479c9a5f719d972e.jpg'},
#     {'id': 18,
#      'name': 'Co-op',
#      'slug': 'co-op',
#      'language': 'eng',
#      'games_count': 5841,
#      'image_background': 'https://media.rawg.io/media/games/c4b/c4b0cab189e73432de3a250d8cf1c84e.jpg'},
#     {'id': 7,
#      'name': 'Multiplayer',
#      'slug': 'multiplayer',
#      'language': 'eng',
#      'games_count': 22282,
#      'image_background': 'https://media.rawg.io/media/games/4a0/4a0a1316102366260e6f38fd2a9cfdce.jpg'},
#     {'id': 31,
#      'name': 'Singleplayer',
#      'slug': 'singleplayer',
#      'language': 'eng',
#      'games_count': 91540,
#      'image_background': 'https://media.rawg.io/media/games/7cf/7cfc9220b401b7a300e409e539c9afd5.jpg'},
#     {'id': 40937,
#      'name': 'Steam Trading Cards',
#      'slug': 'steam-trading-cards-2',
#      'language': 'eng',
#      'games_count': 164,
#      'image_background': 'https://media.rawg.io/media/games/1fa/1fa75f0895240b12fc65cc98ae9649fd.jpg'},
#     {'id': 42392,
#      'name': 'Приключение',
#      'slug': 'prikliuchenie',
#      'language': 'rus',
#      'games_count': 18058,
#      'image_background': 'https://media.rawg.io/media/games/ad2/ad2ffdf80ba993654f31da045bc02456.jpg'},
#     {'id': 42398,
#      'name': 'Инди',
#      'slug': 'indi-2',
#      'language': 'rus',
#      'games_count': 31938,
#      'image_background': 'https://media.rawg.io/media/games/ffe/ffed87105b14f5beff72ff44a7793fd5.jpg'},
#     {'id': 42417,
#      'name': 'Экшен',
#      'slug': 'ekshen',
#      'language': 'rus',
#      'games_count': 20023,
#      'image_background': 'https://media.rawg.io/media/games/8d6/8d69eb6c32ed6acfd75f82d532144993.jpg'},
#     {'id': 43374,
#      'name': 'Remote Play on TV',
#      'slug': 'remote-play-on-tv',
#      'language': 'eng',
#      'games_count': 87,
#      'image_background': 'https://media.rawg.io/media/games/63a/63adb258d31d291ee53168327de6294b.jpg'},
#     {'id': 43577,
#      'name': 'Remote Play on Phone',
#      'slug': 'remote-play-on-phone',
#      'language': 'eng',
#      'games_count': 42,
#      'image_background': 'https://media.rawg.io/media/screenshots/32e/32e2fca8b56687dd33ae966093012671.jpg'},
#     {'id': 43578,
#      'name': 'Remote Play on Tablet',
#      'slug': 'remote-play-on-tablet',
#      'language': 'eng',
#      'games_count': 48,
#      'image_background': 'https://media.rawg.io/media/games/473/473bd9a5e9522629d6cb28b701fb836a.jpg'},
#     {'id': 45201,
#      'name': 'Remote Play Together',
#      'slug': 'remote-play-together',
#      'language': 'eng',
#      'games_count': 435,
#      'image_background': 'https://media.rawg.io/media/screenshots/ce7/ce7c9daceeb5701280e269588742b7aa.jpg'},
#     {'id': 46112,
#      'name': 'Shared/Split Screen Co-op',
#      'slug': 'sharedsplit-screen-co-op',
#      'language': 'eng',
#      'games_count': 301,
#      'image_background': 'https://media.rawg.io/media/screenshots/116/1169f370cdb4976dda3220faa3c57cda.jpg'}],
#    'user_game': None,
#    'reviews_count': 9,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/32e/32e2fca8b56687dd33ae966093012671.jpg'},
#     {'id': 2238508,
#      'image': 'https://media.rawg.io/media/screenshots/d24/d24e5221390894495ae7c8b2262d6a89.jpg'},
#     {'id': 2238509,
#      'image': 'https://media.rawg.io/media/screenshots/9eb/9ebf312150bffe0345222ea1e2e9c983.jpg'},
#     {'id': 2238510,
#      'image': 'https://media.rawg.io/media/screenshots/78c/78c0082a4674338b1b5b83d47ec0ee5e.jpg'},
#     {'id': 2238511,
#      'image': 'https://media.rawg.io/media/screenshots/fce/fce99793b132bd1bdd37bfd963cac856.jpg'},
#     {'id': 2238512,
#      'image': 'https://media.rawg.io/media/screenshots/44a/44a70bbd827c9b7e2969fa90df3d1438.jpg'},
#     {'id': 2238513,
#      'image': 'https://media.rawg.io/media/screenshots/d08/d082ad2d7453a5cf675fc7c85c2795b9.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 2, 'name': 'PlayStation', 'slug': 'playstation'}},
#     {'platform': {'id': 3, 'name': 'Xbox', 'slug': 'xbox'}},
#     {'platform': {'id': 5, 'name': 'Apple Macintosh', 'slug': 'mac'}},
#     {'platform': {'id': 6, 'name': 'Linux', 'slug': 'linux'}},
#     {'platform': {'id': 7, 'name': 'Nintendo', 'slug': 'nintendo'}}],
#    'genres': [{'id': 51, 'name': 'Indie', 'slug': 'indie'},
#     {'id': 3, 'name': 'Adventure', 'slug': 'adventure'},
#     {'id': 4, 'name': 'Action', 'slug': 'action'}]},
#   {'slug': 'the-witcher-3-game-of-the-year',
#    'name': 'The Witcher 3: Game of the Year',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 1, 'name': 'Xbox One', 'slug': 'xbox-one'}},
#     {'platform': {'id': 18, 'name': 'PlayStation 4', 'slug': 'playstation4'}},
#     {'platform': {'id': 7,
#       'name': 'Nintendo Switch',
#       'slug': 'nintendo-switch'}}],
#    'stores': [{'store': {'id': 1, 'name': 'Steam', 'slug': 'steam'}},
#     {'store': {'id': 3,
#       'name': 'PlayStation Store',
#       'slug': 'playstation-store'}},
#     {'store': {'id': 2, 'name': 'Xbox Store', 'slug': 'xbox-store'}},
#     {'store': {'id': 5, 'name': 'GOG', 'slug': 'gog'}},
#     {'store': {'id': 11, 'name': 'Epic Games', 'slug': 'epic-games'}}],
#    'released': '2016-08-30',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/6e1/6e13d9acb4e7a6e184f24892f52c4544.jpg',
#    'rating': 4.77,
#    'rating_top': 5,
#    'ratings': [{'id': 5,
#      'title': 'exceptional',
#      'count': 368,
#      'percent': 83.83},
#     {'id': 4, 'title': 'recommended', 'count': 56, 'percent': 12.76},
#     {'id': 3, 'title': 'meh', 'count': 8, 'percent': 1.82},
#     {'id': 1, 'title': 'skip', 'count': 7, 'percent': 1.59}],
#    'ratings_count': 431,
#    'reviews_text_count': 6,
#    'added': 717,
#    'added_by_status': {'yet': 61,
#     'owned': 189,
#     'beaten': 303,
#     'toplay': 61,
#     'dropped': 28,
#     'playing': 75},
#    'metacritic': 92,
#    'suggestions_count': 88,
#    'id': 257255,
#    'score': None,
#    'clip': {'clip': 'https://media.rawg.io/media/stories-640/396/396f5db6b98c94688ef4ec03a5eea3b9.mp4',
#     'clips': {'320': 'https://media.rawg.io/media/stories-320/4f7/4f72ba353e24467d254acadb98a6ac85.mp4',
#      '640': 'https://media.rawg.io/media/stories-640/396/396f5db6b98c94688ef4ec03a5eea3b9.mp4',
#      'full': 'https://media.rawg.io/media/stories/fac/fac80c4d42421ad8efce4f842c5f3fc1.mp4'},
#     'video': 'QdMXAVhZPb0',
#     'preview': 'https://media.rawg.io/media/stories-previews/a6a/a6ab0d288b870936669d2d0c250c772b.jpg'},
#    'tags': [{'id': 64,
#      'name': 'Fantasy',
#      'slug': 'fantasy',
#      'language': 'eng',
#      'games_count': 10431,
#      'image_background': 'https://media.rawg.io/media/games/63f/63f0e68688cad279ed38cde931dbfcdb.jpg'},
#     {'id': 82,
#      'name': 'Magic',
#      'slug': 'magic',
#      'language': 'eng',
#      'games_count': 3905,
#      'image_background': 'https://media.rawg.io/media/games/e72/e7259ec544cad1c3bac229fa0de46040.jpg'},
#     {'id': 70,
#      'name': 'War',
#      'slug': 'war',
#      'language': 'eng',
#      'games_count': 5968,
#      'image_background': 'https://media.rawg.io/media/games/4e0/4e0e7b6d6906a131307c94266e5c9a1c.jpg'},
#     {'id': 624,
#      'name': 'Monsters',
#      'slug': 'monsters',
#      'language': 'eng',
#      'games_count': 5624,
#      'image_background': 'https://media.rawg.io/media/screenshots/70f/70f42def7984d5b78353229e01f15d67.jpg'},
#     {'id': 941,
#      'name': 'Mountains',
#      'slug': 'mountains',
#      'language': 'eng',
#      'games_count': 1072,
#      'image_background': 'https://media.rawg.io/media/screenshots/f4d/f4d9fea48b84292abe597ee036fcbd4b.jpg'},
#     {'id': 1465,
#      'name': 'combat',
#      'slug': 'combat',
#      'language': 'eng',
#      'games_count': 3968,
#      'image_background': 'https://media.rawg.io/media/screenshots/82a/82ade332e1cfabb9782ec64477a05da3.jpg'},
#     {'id': 1551,
#      'name': 'ancient',
#      'slug': 'ancient',
#      'language': 'eng',
#      'games_count': 1001,
#      'image_background': 'https://media.rawg.io/media/screenshots/5fb/5fbad757fa71162546f26440d62e966a.jpg'},
#     {'id': 1605,
#      'name': 'horse',
#      'slug': 'horse',
#      'language': 'eng',
#      'games_count': 725,
#      'image_background': 'https://media.rawg.io/media/screenshots/f72/f72387a28b17e9589e094edfd428e713.jpg'},
#     {'id': 2184,
#      'name': 'hunt',
#      'slug': 'hunt',
#      'language': 'eng',
#      'games_count': 1890,
#      'image_background': 'https://media.rawg.io/media/screenshots/30e/30e57d6fe1430f0c5c61a1d16a170ac0.jpeg'},
#     {'id': 2326,
#      'name': 'explore',
#      'slug': 'explore',
#      'language': 'eng',
#      'games_count': 2382,
#      'image_background': 'https://media.rawg.io/media/games/bbd/bbd7af2d6dab31e0b3bbfb5f63575ab8.jpg'},
#     {'id': 3046,
#      'name': 'destroy',
#      'slug': 'destroy',
#      'language': 'eng',
#      'games_count': 3422,
#      'image_background': 'https://media.rawg.io/media/screenshots/f81/f81bc39f87a2a85231d0253e072ec945.jpg'},
#     {'id': 3103,
#      'name': 'evil',
#      'slug': 'evil',
#      'language': 'eng',
#      'games_count': 952,
#      'image_background': 'https://media.rawg.io/media/screenshots/00c/00c73c84bbd3bb0ab8291f83c8eb4158.jpg'}],
#    'user_game': None,
#    'reviews_count': 439,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/6e1/6e13d9acb4e7a6e184f24892f52c4544.jpg'},
#     {'id': 1697921,
#      'image': 'https://media.rawg.io/media/screenshots/6e1/6e13d9acb4e7a6e184f24892f52c4544.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 2, 'name': 'PlayStation', 'slug': 'playstation'}},
#     {'platform': {'id': 3, 'name': 'Xbox', 'slug': 'xbox'}},
#     {'platform': {'id': 7, 'name': 'Nintendo', 'slug': 'nintendo'}}],
#    'genres': [{'id': 3, 'name': 'Adventure', 'slug': 'adventure'},
#     {'id': 5, 'name': 'RPG', 'slug': 'role-playing-games-rpg'}]},
#   {'slug': 'mafia-ii-directors-cut',
#    'name': 'Mafia II: Director’s Cut',
#    'playtime': 16,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 5, 'name': 'macOS', 'slug': 'macos'}},
#     {'platform': {'id': 14, 'name': 'Xbox 360', 'slug': 'xbox360'}},
#     {'platform': {'id': 16, 'name': 'PlayStation 3', 'slug': 'playstation3'}}],
#    'stores': [{'store': {'id': 4,
#       'name': 'App Store',
#       'slug': 'apple-appstore'}},
#     {'store': {'id': 5, 'name': 'GOG', 'slug': 'gog'}}],
#    'released': '2011-12-01',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/screenshots/96a/96a1f1158007d6339bcaf1db40a42a87.jpg',
#    'rating': 4.77,
#    'rating_top': 5,
#    'ratings': [{'id': 5,
#      'title': 'exceptional',
#      'count': 10,
#      'percent': 76.92},
#     {'id': 4, 'title': 'recommended', 'count': 3, 'percent': 23.08}],
#    'ratings_count': 13,
#    'reviews_text_count': 0,
#    'added': 52,
#    'added_by_status': {'yet': 4,
#     'owned': 25,
#     'beaten': 17,
#     'toplay': 5,
#     'dropped': 1},
#    'metacritic': None,
#    'suggestions_count': 556,
#    'id': 58118,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 70,
#      'name': 'War',
#      'slug': 'war',
#      'language': 'eng',
#      'games_count': 5968,
#      'image_background': 'https://media.rawg.io/media/games/4e0/4e0e7b6d6906a131307c94266e5c9a1c.jpg'},
#     {'id': 1309,
#      'name': 'hero',
#      'slug': 'hero',
#      'language': 'eng',
#      'games_count': 3704,
#      'image_background': 'https://media.rawg.io/media/screenshots/cd1/cd1dedeafe91fa1d9034dba0c3dcb1f7.jpg'},
#     {'id': 3942,
#      'name': 'rage',
#      'slug': 'rage',
#      'language': 'eng',
#      'games_count': 730,
#      'image_background': 'https://media.rawg.io/media/screenshots/06a/06a096a0142a08f1754310ffb1d7c145.jpg'}],
#    'user_game': None,
#    'reviews_count': 13,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/screenshots/96a/96a1f1158007d6339bcaf1db40a42a87.jpg'},
#     {'id': 765911,
#      'image': 'https://media.rawg.io/media/screenshots/a5c/a5c0b470458b31615156da0eb32d7131.jpg'},
#     {'id': 765912,
#      'image': 'https://media.rawg.io/media/screenshots/ebe/ebe05525c8f650f4ecf5c3e6e617bbef.jpg'},
#     {'id': 765913,
#      'image': 'https://media.rawg.io/media/screenshots/716/716b0394e41d236c413cc07ea6265039.jpg'},
#     {'id': 765914,
#      'image': 'https://media.rawg.io/media/screenshots/806/8066ec2ee7dd7e95d1fbb9bd3b59851d.jpg'},
#     {'id': 765915,
#      'image': 'https://media.rawg.io/media/screenshots/185/185eb476be55fd80206ef6e269c3567e.jpg'},
#     {'id': 765916,
#      'image': 'https://media.rawg.io/media/screenshots/8f0/8f0b781ee1917c3167b3ae7c63d123b7.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 2, 'name': 'PlayStation', 'slug': 'playstation'}},
#     {'platform': {'id': 3, 'name': 'Xbox', 'slug': 'xbox'}},
#     {'platform': {'id': 5, 'name': 'Apple Macintosh', 'slug': 'mac'}}],
#    'genres': [{'id': 3, 'name': 'Adventure', 'slug': 'adventure'},
#     {'id': 4, 'name': 'Action', 'slug': 'action'}]},
#   {'slug': 'mass-effect-trilogy',
#    'name': 'Mass Effect Trilogy',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 16, 'name': 'PlayStation 3', 'slug': 'playstation3'}}],
#    'stores': [{'store': {'id': 3,
#       'name': 'PlayStation Store',
#       'slug': 'playstation-store'}}],
#    'released': '2012-11-06',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/games/036/036b0631f855ec96a4a2065511635116.jpg',
#    'rating': 4.75,
#    'rating_top': 5,
#    'ratings': [{'id': 5, 'title': 'exceptional', 'count': 80, 'percent': 80.0},
#     {'id': 4, 'title': 'recommended', 'count': 17, 'percent': 17.0},
#     {'id': 3, 'title': 'meh', 'count': 2, 'percent': 2.0},
#     {'id': 1, 'title': 'skip', 'count': 1, 'percent': 1.0}],
#    'ratings_count': 100,
#    'reviews_text_count': 0,
#    'added': 173,
#    'added_by_status': {'yet': 12,
#     'owned': 42,
#     'beaten': 91,
#     'toplay': 21,
#     'dropped': 5,
#     'playing': 2},
#    'metacritic': None,
#    'suggestions_count': 607,
#    'id': 4167,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 70,
#      'name': 'War',
#      'slug': 'war',
#      'language': 'eng',
#      'games_count': 5968,
#      'image_background': 'https://media.rawg.io/media/games/4e0/4e0e7b6d6906a131307c94266e5c9a1c.jpg'},
#     {'id': 1551,
#      'name': 'ancient',
#      'slug': 'ancient',
#      'language': 'eng',
#      'games_count': 1001,
#      'image_background': 'https://media.rawg.io/media/screenshots/5fb/5fbad757fa71162546f26440d62e966a.jpg'},
#     {'id': 5816,
#      'name': 'console',
#      'slug': 'console',
#      'language': 'eng',
#      'games_count': 1157,
#      'image_background': 'https://media.rawg.io/media/screenshots/aa0/aa094734c533a4c8636f095fcf9ec76e.jpg'}],
#    'user_game': None,
#    'reviews_count': 100,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/games/036/036b0631f855ec96a4a2065511635116.jpg'},
#     {'id': 607363,
#      'image': 'https://media.rawg.io/media/screenshots/aee/aeee1cf425eecd9df7ddb18a7934643c.jpg'},
#     {'id': 607364,
#      'image': 'https://media.rawg.io/media/screenshots/d53/d53b00ea810dc5616dcc2db90a964869.jpg'},
#     {'id': 607365,
#      'image': 'https://media.rawg.io/media/screenshots/c11/c110210f4129a5b429778837b6067a85.jpg'},
#     {'id': 607366,
#      'image': 'https://media.rawg.io/media/screenshots/93a/93a39d94b55062186c8ad81051fa3f7a.jpg'},
#     {'id': 607367,
#      'image': 'https://media.rawg.io/media/screenshots/bda/bda4afdbea1ea945236f892da4718718.jpg'},
#     {'id': 607368,
#      'image': 'https://media.rawg.io/media/screenshots/9b1/9b1c6509a05d5a8062b4557a59dd5aca.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 2, 'name': 'PlayStation', 'slug': 'playstation'}}],
#    'genres': [{'id': 2, 'name': 'Shooter', 'slug': 'shooter'},
#     {'id': 4, 'name': 'Action', 'slug': 'action'},
#     {'id': 5, 'name': 'RPG', 'slug': 'role-playing-games-rpg'}]},
#   {'slug': 'the-witcher-3-wild-hunt-blood-and-wine',
#    'name': 'The Witcher 3: Wild Hunt - Blood and Wine',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 1, 'name': 'Xbox One', 'slug': 'xbox-one'}},
#     {'platform': {'id': 18, 'name': 'PlayStation 4', 'slug': 'playstation4'}}],
#    'stores': [{'store': {'id': 1, 'name': 'Steam', 'slug': 'steam'}},
#     {'store': {'id': 3,
#       'name': 'PlayStation Store',
#       'slug': 'playstation-store'}},
#     {'store': {'id': 2, 'name': 'Xbox Store', 'slug': 'xbox-store'}},
#     {'store': {'id': 5, 'name': 'GOG', 'slug': 'gog'}}],
#    'released': '2016-05-30',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/games/b51/b51c3649322ac0de9dfbe83435eda449.jpg',
#    'rating': 4.75,
#    'rating_top': 5,
#    'ratings': [{'id': 5,
#      'title': 'exceptional',
#      'count': 270,
#      'percent': 82.57},
#     {'id': 4, 'title': 'recommended', 'count': 42, 'percent': 12.84},
#     {'id': 3, 'title': 'meh', 'count': 10, 'percent': 3.06},
#     {'id': 1, 'title': 'skip', 'count': 5, 'percent': 1.53}],
#    'ratings_count': 325,
#    'reviews_text_count': 2,
#    'added': 550,
#    'added_by_status': {'yet': 57,
#     'owned': 120,
#     'beaten': 299,
#     'toplay': 36,
#     'dropped': 9,
#     'playing': 29},
#    'metacritic': 92,
#    'suggestions_count': 660,
#    'id': 43252,
#    'score': None,
#    'clip': {'clip': 'https://media.rawg.io/media/stories-640/d73/d7395ffe4593537c3325d248cb16f0b0.mp4',
#     'clips': {'320': 'https://media.rawg.io/media/stories-320/e22/e2249c682b01832b68d65b2a1ec3a7ef.mp4',
#      '640': 'https://media.rawg.io/media/stories-640/d73/d7395ffe4593537c3325d248cb16f0b0.mp4',
#      'full': 'https://media.rawg.io/media/stories/e4e/e4eaa07721af4beaebce18a92b46fb27.mp4'},
#     'video': 'pb63ThY4UEA',
#     'preview': 'https://media.rawg.io/media/stories-previews/71d/71d05cef8c4c70cf3406df8512f9838d.jpg'},
#    'tags': [{'id': 270,
#      'name': 'Blood',
#      'slug': 'blood',
#      'language': 'eng',
#      'games_count': 1352,
#      'image_background': 'https://media.rawg.io/media/games/aa3/aa36ba4b486a03ddfaef274fb4f5afd4.jpg'},
#     {'id': 16,
#      'name': 'Horror',
#      'slug': 'horror',
#      'language': 'eng',
#      'games_count': 17393,
#      'image_background': 'https://media.rawg.io/media/games/dd5/dd50d4266915d56dd5b63ae1bf72606a.jpg'},
#     {'id': 70,
#      'name': 'War',
#      'slug': 'war',
#      'language': 'eng',
#      'games_count': 5968,
#      'image_background': 'https://media.rawg.io/media/games/4e0/4e0e7b6d6906a131307c94266e5c9a1c.jpg'},
#     {'id': 892,
#      'name': 'love',
#      'slug': 'love',
#      'language': 'eng',
#      'games_count': 5230,
#      'image_background': 'https://media.rawg.io/media/screenshots/dad/dada50036cd7c649ec7570c3e42b0a6c.jpg'}],
#    'user_game': None,
#    'reviews_count': 327,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/games/b51/b51c3649322ac0de9dfbe83435eda449.jpg'},
#     {'id': 624498,
#      'image': 'https://media.rawg.io/media/screenshots/88b/88bd812b03e695f608ec6465f9290708.jpg'},
#     {'id': 624499,
#      'image': 'https://media.rawg.io/media/screenshots/777/7773199e9937c4ed2a6cc4088a06f70e_PfIohkJ.jpg'},
#     {'id': 624500,
#      'image': 'https://media.rawg.io/media/screenshots/c89/c89a7a75b45396d2c7ca65c76a5bacd4.jpg'},
#     {'id': 624501,
#      'image': 'https://media.rawg.io/media/screenshots/765/76520164dcd57ca54e812152cdca4ece.jpg'},
#     {'id': 624502,
#      'image': 'https://media.rawg.io/media/screenshots/ce4/ce4aa0c24a7f584b208a4fb0581ed3dd_M7g8MQj.jpg'},
#     {'id': 624503,
#      'image': 'https://media.rawg.io/media/screenshots/742/7425367f0c342b4f7e1008524e0407fa.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 2, 'name': 'PlayStation', 'slug': 'playstation'}},
#     {'platform': {'id': 3, 'name': 'Xbox', 'slug': 'xbox'}}],
#    'genres': [{'id': 5, 'name': 'RPG', 'slug': 'role-playing-games-rpg'}]},
#   {'slug': 'the-witcher-3-wild-hunt-hearts-of-stone',
#    'name': 'The Witcher 3: Wild Hunt - Hearts of Stone',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 1, 'name': 'Xbox One', 'slug': 'xbox-one'}},
#     {'platform': {'id': 18, 'name': 'PlayStation 4', 'slug': 'playstation4'}}],
#    'stores': [{'store': {'id': 1, 'name': 'Steam', 'slug': 'steam'}},
#     {'store': {'id': 3,
#       'name': 'PlayStation Store',
#       'slug': 'playstation-store'}},
#     {'store': {'id': 2, 'name': 'Xbox Store', 'slug': 'xbox-store'}},
#     {'store': {'id': 5, 'name': 'GOG', 'slug': 'gog'}}],
#    'released': '2015-10-13',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/games/c19/c193180583c34e5753a1aaf15a586761.jpg',
#    'rating': 4.74,
#    'rating_top': 5,
#    'ratings': [{'id': 5,
#      'title': 'exceptional',
#      'count': 304,
#      'percent': 79.58},
#     {'id': 4, 'title': 'recommended', 'count': 67, 'percent': 17.54},
#     {'id': 3, 'title': 'meh', 'count': 6, 'percent': 1.57},
#     {'id': 1, 'title': 'skip', 'count': 5, 'percent': 1.31}],
#    'ratings_count': 381,
#    'reviews_text_count': 1,
#    'added': 582,
#    'added_by_status': {'yet': 46,
#     'owned': 131,
#     'beaten': 346,
#     'toplay': 29,
#     'dropped': 11,
#     'playing': 19},
#    'metacritic': 90,
#    'suggestions_count': 576,
#    'id': 43050,
#    'score': None,
#    'clip': {'clip': 'https://media.rawg.io/media/stories-640/2d4/2d48c6ff94bfbe9f4f732f3ab070de34.mp4',
#     'clips': {'320': 'https://media.rawg.io/media/stories-320/b28/b285102d00be84ff069572fb64a63780.mp4',
#      '640': 'https://media.rawg.io/media/stories-640/2d4/2d48c6ff94bfbe9f4f732f3ab070de34.mp4',
#      'full': 'https://media.rawg.io/media/stories/3df/3df703f14d568fb2b6816748c8821d7b.mp4'},
#     'video': 'AleQVXLQ5Fc',
#     'preview': 'https://media.rawg.io/media/stories-previews/d42/d4245e0e0689a3558aaeb75bfa431875.jpg'},
#    'tags': [{'id': 217,
#      'name': 'Romance',
#      'slug': 'romance',
#      'language': 'eng',
#      'games_count': 2861,
#      'image_background': 'https://media.rawg.io/media/games/736/736e1e2e7670169114a48b5f65f66bdb.jpg'},
#     {'id': 624,
#      'name': 'Monsters',
#      'slug': 'monsters',
#      'language': 'eng',
#      'games_count': 5624,
#      'image_background': 'https://media.rawg.io/media/screenshots/70f/70f42def7984d5b78353229e01f15d67.jpg'},
#     {'id': 2184,
#      'name': 'hunt',
#      'slug': 'hunt',
#      'language': 'eng',
#      'games_count': 1890,
#      'image_background': 'https://media.rawg.io/media/screenshots/30e/30e57d6fe1430f0c5c61a1d16a170ac0.jpeg'},
#     {'id': 5777,
#      'name': 'pack',
#      'slug': 'pack',
#      'language': 'eng',
#      'games_count': 1615,
#      'image_background': 'https://media.rawg.io/media/games/c06/c06edf54c45016c6e5edc2235a29c7d3.jpg'}],
#    'user_game': None,
#    'reviews_count': 382,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/games/c19/c193180583c34e5753a1aaf15a586761.jpg'},
#     {'id': 622834,
#      'image': 'https://media.rawg.io/media/screenshots/795/795e17029d6e4439646ca719621b292b.jpg'},
#     {'id': 622835,
#      'image': 'https://media.rawg.io/media/screenshots/8fc/8fcaf0f314c81bd641e0ee6e88c8ed48.jpg'},
#     {'id': 622836,
#      'image': 'https://media.rawg.io/media/screenshots/aea/aea6d80d9df234736998becb665c80a9.jpg'},
#     {'id': 622837,
#      'image': 'https://media.rawg.io/media/screenshots/505/505cdd08146f0d1d624cc637e65b5d27.jpg'},
#     {'id': 622838,
#      'image': 'https://media.rawg.io/media/screenshots/f8e/f8e8ec95bb5a090f9cbfc49b8098744e.jpg'},
#     {'id': 622839,
#      'image': 'https://media.rawg.io/media/screenshots/0a1/0a1d658c9ab867c7f7fa7b2517673835.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 2, 'name': 'PlayStation', 'slug': 'playstation'}},
#     {'platform': {'id': 3, 'name': 'Xbox', 'slug': 'xbox'}}],
#    'genres': [{'id': 5, 'name': 'RPG', 'slug': 'role-playing-games-rpg'}]},
#   {'slug': 'metal-gear-solid-the-definitive-experience',
#    'name': 'METAL GEAR SOLID V: THE DEFINITIVE EXPERIENCE',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 1, 'name': 'Xbox One', 'slug': 'xbox-one'}},
#     {'platform': {'id': 18, 'name': 'PlayStation 4', 'slug': 'playstation4'}}],
#    'stores': [{'store': {'id': 3,
#       'name': 'PlayStation Store',
#       'slug': 'playstation-store'}},
#     {'store': {'id': 2, 'name': 'Xbox Store', 'slug': 'xbox-store'}}],
#    'released': '2016-10-11',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/games/72b/72bfec99eb3127c4e01fd60f79133965.jpg',
#    'rating': 4.74,
#    'rating_top': 5,
#    'ratings': [{'id': 5,
#      'title': 'exceptional',
#      'count': 18,
#      'percent': 78.26},
#     {'id': 4, 'title': 'recommended', 'count': 4, 'percent': 17.39},
#     {'id': 3, 'title': 'meh', 'count': 1, 'percent': 4.35}],
#    'ratings_count': 22,
#    'reviews_text_count': 1,
#    'added': 71,
#    'added_by_status': {'yet': 18,
#     'owned': 16,
#     'beaten': 19,
#     'toplay': 13,
#     'dropped': 4,
#     'playing': 1},
#    'metacritic': None,
#    'suggestions_count': 627,
#    'id': 1111,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 7,
#      'name': 'Multiplayer',
#      'slug': 'multiplayer',
#      'language': 'eng',
#      'games_count': 22431,
#      'image_background': 'https://media.rawg.io/media/games/88c/88c5b4d7c80276c03ff62aebb1a99ad4.jpg'},
#     {'id': 15,
#      'name': 'Stealth',
#      'slug': 'stealth',
#      'language': 'eng',
#      'games_count': 3215,
#      'image_background': 'https://media.rawg.io/media/games/daa/daaee07fcb40744d90cf8142f94a241f.jpg'},
#     {'id': 406,
#      'name': 'Story',
#      'slug': 'story',
#      'language': 'eng',
#      'games_count': 7553,
#      'image_background': 'https://media.rawg.io/media/games/8ee/8eed88e297441ef9202b5d1d35d7d86f.jpg'},
#     {'id': 413,
#      'name': 'online',
#      'slug': 'online',
#      'language': 'eng',
#      'games_count': 5214,
#      'image_background': 'https://media.rawg.io/media/screenshots/772/77272915ed66e464986ad6afcdf52407.jpg'},
#     {'id': 1626,
#      'name': 'collection',
#      'slug': 'collection',
#      'language': 'eng',
#      'games_count': 2797,
#      'image_background': 'https://media.rawg.io/media/screenshots/7ee/7ee96ff4c0297175c9ea90e45dec221b.jpg'},
#     {'id': 1788,
#      'name': 'metal',
#      'slug': 'metal',
#      'language': 'eng',
#      'games_count': 618,
#      'image_background': 'https://media.rawg.io/media/games/68d/68dea65a86e55d75c156d625e3631133.jpg'},
#     {'id': 5641,
#      'name': 'bundle',
#      'slug': 'bundle',
#      'language': 'eng',
#      'games_count': 256,
#      'image_background': 'https://media.rawg.io/media/screenshots/dca/dca322b06cf8f8927737b24e10658dd2.jpg'}],
#    'user_game': None,
#    'reviews_count': 23,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/games/72b/72bfec99eb3127c4e01fd60f79133965.jpg'},
#     {'id': 9748,
#      'image': 'https://media.rawg.io/media/screenshots/d31/d318d170035baf9d18e3b28d0949e99f.jpg'},
#     {'id': 9752,
#      'image': 'https://media.rawg.io/media/screenshots/aa8/aa8fc177e0771155eef2f1e207e03ce7.jpg'},
#     {'id': 9756,
#      'image': 'https://media.rawg.io/media/screenshots/e91/e91805bfc5696c3364f91167e8b873c6.jpg'},
#     {'id': 9760,
#      'image': 'https://media.rawg.io/media/screenshots/42e/42e634389f5de820a6834437b78a3893.jpg'},
#     {'id': 9764,
#      'image': 'https://media.rawg.io/media/screenshots/09a/09a68789d670ed36f60ad35c648774ae.jpg'},
#     {'id': 9767,
#      'image': 'https://media.rawg.io/media/screenshots/8e2/8e24c7b8293df8479db973568b4376d8.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 2, 'name': 'PlayStation', 'slug': 'playstation'}},
#     {'platform': {'id': 3, 'name': 'Xbox', 'slug': 'xbox'}}],
#    'genres': [{'id': 4, 'name': 'Action', 'slug': 'action'}]},
#   {'slug': 'dark-souls-iii-the-ringed-city',
#    'name': 'Dark Souls III: The Ringed City',
#    'playtime': 0,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 1, 'name': 'Xbox One', 'slug': 'xbox-one'}},
#     {'platform': {'id': 18, 'name': 'PlayStation 4', 'slug': 'playstation4'}}],
#    'stores': [{'store': {'id': 1, 'name': 'Steam', 'slug': 'steam'}},
#     {'store': {'id': 3,
#       'name': 'PlayStation Store',
#       'slug': 'playstation-store'}},
#     {'store': {'id': 2, 'name': 'Xbox Store', 'slug': 'xbox-store'}}],
#    'released': '2017-03-28',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/games/25a/25a2a77f6feb0b14bcb0847ed966db20.jpg',
#    'rating': 4.74,
#    'rating_top': 5,
#    'ratings': [{'id': 5,
#      'title': 'exceptional',
#      'count': 18,
#      'percent': 78.26},
#     {'id': 4, 'title': 'recommended', 'count': 4, 'percent': 17.39},
#     {'id': 3, 'title': 'meh', 'count': 1, 'percent': 4.35}],
#    'ratings_count': 23,
#    'reviews_text_count': 0,
#    'added': 58,
#    'added_by_status': {'yet': 3,
#     'owned': 6,
#     'beaten': 39,
#     'toplay': 6,
#     'dropped': 2,
#     'playing': 2},
#    'metacritic': 83,
#    'suggestions_count': 246,
#    'id': 385406,
#    'score': None,
#    'clip': None,
#    'tags': [{'id': 40299,
#      'name': 'medieval-fantasy',
#      'slug': 'medieval-fantasy',
#      'language': 'eng',
#      'games_count': 4,
#      'image_background': 'https://media.rawg.io/media/screenshots/cb2/cb27293e76a0a07e8ac69dc48d89d81f.jpg'},
#     {'id': 45501,
#      'name': 'soulsborne',
#      'slug': 'soulsborne',
#      'language': 'eng',
#      'games_count': 3,
#      'image_background': 'https://media.rawg.io/media/games/25a/25a2a77f6feb0b14bcb0847ed966db20.jpg'}],
#    'user_game': None,
#    'reviews_count': 23,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
# ...
#      'full': 'https://media.rawg.io/media/stories/176/176b6308428ae115cfa6af7ddeb06aea.mp4'},
#     'video': 'P4ItlzttkkU',
#     'preview': 'https://media.rawg.io/media/stories-previews/0c9/0c979467231b82939bd75144490c3dfe.jpg'},
#    'tags': [{'id': 69,
#      'name': 'Action-Adventure',
#      'slug': 'action-adventure',
#      'language': 'eng',
#      'games_count': 6238,
#      'image_background': 'https://media.rawg.io/media/games/569/56978b5a77f13aa2ec5d09ec81d01cad.jpg'},
#     {'id': 97,
#      'name': 'Action RPG',
#      'slug': 'action-rpg',
#      'language': 'eng',
#      'games_count': 2840,
#      'image_background': 'https://media.rawg.io/media/games/364/3642d850efb217c58feab80b8affaa89.jpg'},
#     {'id': 13,
#      'name': 'Atmospheric',
#      'slug': 'atmospheric',
#      'language': 'eng',
#      'games_count': 10280,
#      'image_background': 'https://media.rawg.io/media/games/91c/91c4f377c1e09755b60a0102c5252843.jpg'},
#     {'id': 7,
#      'name': 'Multiplayer',
#      'slug': 'multiplayer',
#      'language': 'eng',
#      'games_count': 22431,
#      'image_background': 'https://media.rawg.io/media/games/88c/88c5b4d7c80276c03ff62aebb1a99ad4.jpg'},
#     {'id': 15,
#      'name': 'Stealth',
#      'slug': 'stealth',
#      'language': 'eng',
#      'games_count': 3215,
#      'image_background': 'https://media.rawg.io/media/games/daa/daaee07fcb40744d90cf8142f94a241f.jpg'},
#     {'id': 1,
#      'name': 'Survival',
#      'slug': 'survival',
#      'language': 'eng',
#      'games_count': 4067,
#      'image_background': 'https://media.rawg.io/media/games/4fb/4fb548e4816c84d1d70f1a228fb167cc.jpg'},
#     {'id': 63,
#      'name': 'Zombies',
#      'slug': 'zombies',
#      'language': 'eng',
#      'games_count': 5857,
#      'image_background': 'https://media.rawg.io/media/games/f14/f1422eacab98c5f85a5123da4e9d9e89.jpg'},
#     {'id': 478,
#      'name': '3rd-Person Perspective',
#      'slug': '3rd-person-perspective',
#      'language': 'eng',
#      'games_count': 81,
#      'image_background': 'https://media.rawg.io/media/games/709/709bf81f874ce5d25d625b37b014cb63.jpg'},
#     {'id': 37796,
#      'name': 'exclusive',
#      'slug': 'exclusive',
#      'language': 'eng',
#      'games_count': 4453,
#      'image_background': 'https://media.rawg.io/media/screenshots/0f5/0f585fa72f534f62f9e5da051179f5de.jpg'}],
#    'user_game': None,
#    'reviews_count': 2117,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/games/364/3642d850efb217c58feab80b8affaa89.jpg'},
#     {'id': 208251,
#      'image': 'https://media.rawg.io/media/screenshots/5a7/5a74e852355169e1767f3b59d5488829.jpeg'},
#     {'id': 208252,
#      'image': 'https://media.rawg.io/media/screenshots/a4b/a4b8e8d4d56d1889f76872da7364e406.jpeg'},
#     {'id': 208253,
#      'image': 'https://media.rawg.io/media/screenshots/1ba/1babd5640e3eed7646b6f2834daab303.jpeg'},
#     {'id': 208254,
#      'image': 'https://media.rawg.io/media/screenshots/9ce/9ce9018611e2931782b87ef8b4bcd012.jpeg'},
#     {'id': 208255,
#      'image': 'https://media.rawg.io/media/screenshots/5c9/5c9c1f58a945bb06f5467587a9d6d0e4.jpeg'},
#     {'id': 208256,
#      'image': 'https://media.rawg.io/media/screenshots/6ea/6ea8e1f3d812f7218f9205c1dd658147.jpeg'}],
#    'parent_platforms': [{'platform': {'id': 2,
#       'name': 'PlayStation',
#       'slug': 'playstation'}}],
#    'genres': [{'id': 3, 'name': 'Adventure', 'slug': 'adventure'},
#     {'id': 4, 'name': 'Action', 'slug': 'action'}]},
#   {'slug': 'the-witcher-3-wild-hunt',
#    'name': 'The Witcher 3: Wild Hunt',
#    'playtime': 52,
#    'platforms': [{'platform': {'id': 4, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 1, 'name': 'Xbox One', 'slug': 'xbox-one'}},
#     {'platform': {'id': 18, 'name': 'PlayStation 4', 'slug': 'playstation4'}},
#     {'platform': {'id': 7,
#       'name': 'Nintendo Switch',
#       'slug': 'nintendo-switch'}}],
#    'stores': [{'store': {'id': 1, 'name': 'Steam', 'slug': 'steam'}},
#     {'store': {'id': 3,
#       'name': 'PlayStation Store',
#       'slug': 'playstation-store'}},
#     {'store': {'id': 2, 'name': 'Xbox Store', 'slug': 'xbox-store'}},
#     {'store': {'id': 5, 'name': 'GOG', 'slug': 'gog'}}],
#    'released': '2015-05-18',
#    'tba': False,
#    'background_image': 'https://media.rawg.io/media/games/618/618c2031a07bbff6b4f611f10b6bcdbc.jpg',
#    'rating': 4.68,
#    'rating_top': 5,
#    'ratings': [{'id': 5,
#      'title': 'exceptional',
#      'count': 3077,
#      'percent': 78.22},
#     {'id': 4, 'title': 'recommended', 'count': 616, 'percent': 15.66},
#     {'id': 3, 'title': 'meh', 'count': 154, 'percent': 3.91},
#     {'id': 1, 'title': 'skip', 'count': 87, 'percent': 2.21}],
#    'ratings_count': 3877,
#    'reviews_text_count': 42,
#    'added': 11580,
#    'added_by_status': {'yet': 620,
#     'owned': 6637,
#     'beaten': 2702,
#     'toplay': 510,
#     'dropped': 476,
#     'playing': 635},
#    'metacritic': 92,
#    'suggestions_count': 688,
#    'id': 3328,
#    'score': None,
#    'clip': {'clip': 'https://media.rawg.io/media/stories-640/619/6197079f588ae10e3fe87edad3ee2d43.mp4',
#     'clips': {'320': 'https://media.rawg.io/media/stories-320/310/3109cc6c6168db8a03acc45f7edf5109.mp4',
#      '640': 'https://media.rawg.io/media/stories-640/619/6197079f588ae10e3fe87edad3ee2d43.mp4',
#      'full': 'https://media.rawg.io/media/stories/a25/a257f298e1de01ef2a077da02a5c8ee8.mp4'},
#     'video': '2bSk-8C76dc',
#     'preview': 'https://media.rawg.io/media/stories-previews/5ac/5ac124b0b14e2bc794bedb240870d1f4.jpg'},
#    'tags': [{'id': 40836,
#      'name': 'Full controller support',
#      'slug': 'full-controller-support',
#      'language': 'eng',
#      'games_count': 9377,
#      'image_background': 'https://media.rawg.io/media/games/d1a/d1a2e99ade53494c6330a0ed945fe823.jpg'},
#     {'id': 97,
#      'name': 'Action RPG',
#      'slug': 'action-rpg',
#      'language': 'eng',
#      'games_count': 2840,
#      'image_background': 'https://media.rawg.io/media/games/364/3642d850efb217c58feab80b8affaa89.jpg'},
#     {'id': 13,
#      'name': 'Atmospheric',
#      'slug': 'atmospheric',
#      'language': 'eng',
#      'games_count': 10280,
#      'image_background': 'https://media.rawg.io/media/games/91c/91c4f377c1e09755b60a0102c5252843.jpg'},
#     {'id': 145,
#      'name': 'Choices Matter',
#      'slug': 'choices-matter',
#      'language': 'eng',
#      'games_count': 728,
#      'image_background': 'https://media.rawg.io/media/games/a6c/a6ccd34125c594abf1a9c9821b9a715d.jpg'},
#     {'id': 41,
#      'name': 'Dark',
#      'slug': 'dark',
#      'language': 'eng',
#      'games_count': 5970,
#      'image_background': 'https://media.rawg.io/media/games/dbe/dbeeb30e02b59f55c4d8cf4f103a83b9.jpg'},
#     {'id': 40,
#      'name': 'Dark Fantasy',
#      'slug': 'dark-fantasy',
#      'language': 'eng',
#      'games_count': 1247,
#      'image_background': 'https://media.rawg.io/media/games/886/8868f9ea0c91d45316319ebf5dd4fc64.jpg'},
#     {'id': 64,
#      'name': 'Fantasy',
#      'slug': 'fantasy',
#      'language': 'eng',
#      'games_count': 10431,
#      'image_background': 'https://media.rawg.io/media/games/63f/63f0e68688cad279ed38cde931dbfcdb.jpg'},
#     {'id': 42,
#      'name': 'Great Soundtrack',
#      'slug': 'great-soundtrack',
#      'language': 'eng',
#      'games_count': 3087,
#      'image_background': 'https://media.rawg.io/media/games/ee3/ee3e10193aafc3230ba1cae426967d10.jpg'},
#     {'id': 82,
#      'name': 'Magic',
#      'slug': 'magic',
#      'language': 'eng',
#      'games_count': 3905,
#      'image_background': 'https://media.rawg.io/media/games/e72/e7259ec544cad1c3bac229fa0de46040.jpg'},
#     {'id': 192,
#      'name': 'Mature',
#      'slug': 'mature',
#      'language': 'eng',
#      'games_count': 724,
#      'image_background': 'https://media.rawg.io/media/games/a34/a348e613424260bc7e034fb6031c762e.jpg'},
#     {'id': 66,
#      'name': 'Medieval',
#      'slug': 'medieval',
#      'language': 'eng',
#      'games_count': 2237,
#      'image_background': 'https://media.rawg.io/media/games/7d9/7d9fd2b2b53a27f1af20b96b8d40c538.jpg'},
#     {'id': 218,
#      'name': 'Multiple Endings',
#      'slug': 'multiple-endings',
#      'language': 'eng',
#      'games_count': 2523,
#      'image_background': 'https://media.rawg.io/media/games/e72/e7259ec544cad1c3bac229fa0de46040.jpg'},
#     {'id': 44,
#      'name': 'Nudity',
#      'slug': 'nudity',
#      'language': 'eng',
#      'games_count': 2177,
#      'image_background': 'https://media.rawg.io/media/games/16b/16b1b7b36e2042d1128d5a3e852b3b2f.jpg'},
#     {'id': 36,
#      'name': 'Open World',
#      'slug': 'open-world',
#      'language': 'eng',
#      'games_count': 3088,
#      'image_background': 'https://media.rawg.io/media/games/b45/b45575f34285f2c4479c9a5f719d972e.jpg'},
#     {'id': 24,
#      'name': 'RPG',
#      'slug': 'rpg',
#      'language': 'eng',
#      'games_count': 10513,
#      'image_background': 'https://media.rawg.io/media/games/e2d/e2d3f396b16dded0f841c17c9799a882.jpg'},
#     {'id': 37,
#      'name': 'Sandbox',
#      'slug': 'sandbox',
#      'language': 'eng',
#      'games_count': 2909,
#      'image_background': 'https://media.rawg.io/media/games/15c/15c95a4915f88a3e89c821526afe05fc.jpg'},
#     {'id': 31,
#      'name': 'Singleplayer',
#      'slug': 'singleplayer',
#      'language': 'eng',
#      'games_count': 92374,
#      'image_background': 'https://media.rawg.io/media/games/d58/d588947d4286e7b5e0e12e1bea7d9844.jpg'},
#     {'id': 118,
#      'name': 'Story Rich',
#      'slug': 'story-rich',
#      'language': 'eng',
#      'games_count': 7867,
#      'image_background': 'https://media.rawg.io/media/games/120/1201a40e4364557b124392ee50317b99.jpg'},
#     {'id': 149,
#      'name': 'Third Person',
#      'slug': 'third-person',
#      'language': 'eng',
#      'games_count': 3079,
#      'image_background': 'https://media.rawg.io/media/games/f87/f87457e8347484033cb34cde6101d08d.jpg'},
#     {'id': 336,
#      'name': 'controller support',
#      'slug': 'controller-support',
#      'language': 'eng',
#      'games_count': 292,
#      'image_background': 'https://media.rawg.io/media/games/5c0/5c0dd63002cb23f804aab327d40ef119.jpg'},
#     {'id': 42390,
#      'name': 'Решения с последствиями',
#      'slug': 'resheniia-s-posledstviiami',
#      'language': 'rus',
#      'games_count': 1016,
#      'image_background': 'https://media.rawg.io/media/games/264/2642b17a7885f7abc4fd018e98943242.jpg'},
#     {'id': 42391,
#      'name': 'Средневековье',
#      'slug': 'srednevekove',
#      'language': 'rus',
#      'games_count': 581,
#      'image_background': 'https://media.rawg.io/media/games/f32/f3240d0b7a9e6523c8d708129c512ac8.jpg'},
#     {'id': 42392,
#      'name': 'Приключение',
#      'slug': 'prikliuchenie',
#      'language': 'rus',
#      'games_count': 18132,
#      'image_background': 'https://media.rawg.io/media/games/511/5118aff5091cb3efec399c808f8c598f.jpg'},
#     {'id': 42394,
#      'name': 'Глубокий сюжет',
#      'slug': 'glubokii-siuzhet',
#      'language': 'rus',
#      'games_count': 3633,
#      'image_background': 'https://media.rawg.io/media/games/b49/b4912b5dbfc7ed8927b65f05b8507f6c.jpg'},
#     {'id': 42396,
#      'name': 'Для одного игрока',
#      'slug': 'dlia-odnogo-igroka',
#      'language': 'rus',
#      'games_count': 12250,
#      'image_background': 'https://media.rawg.io/media/games/618/618c2031a07bbff6b4f611f10b6bcdbc.jpg'},
#     {'id': 42400,
#      'name': 'Атмосфера',
#      'slug': 'atmosfera',
#      'language': 'rus',
#      'games_count': 4880,
#      'image_background': 'https://media.rawg.io/media/games/198/1988a337305e008b41d7f536ce9b73f6.jpg'},
#     {'id': 42401,
#      'name': 'Отличный саундтрек',
#      'slug': 'otlichnyi-saundtrek',
#      'language': 'rus',
#      'games_count': 4319,
#      'image_background': 'https://media.rawg.io/media/games/ee3/ee3e10193aafc3230ba1cae426967d10.jpg'},
#     {'id': 42406,
#      'name': 'Нагота',
#      'slug': 'nagota',
#      'language': 'rus',
#      'games_count': 1985,
#      'image_background': 'https://media.rawg.io/media/games/d8f/d8f3b28fc747ed6f92943cdd33fb91b5.jpeg'},
#     {'id': 42412,
#      'name': 'Ролевая игра',
#      'slug': 'rolevaia-igra',
#      'language': 'rus',
#      'games_count': 8022,
#      'image_background': 'https://media.rawg.io/media/games/ee3/ee3e10193aafc3230ba1cae426967d10.jpg'},
#     {'id': 42417,
#      'name': 'Экшен',
#      'slug': 'ekshen',
#      'language': 'rus',
#      'games_count': 20094,
#      'image_background': 'https://media.rawg.io/media/games/b7b/b7b8381707152afc7d91f5d95de70e39.jpg'},
#     {'id': 42435,
#      'name': 'Шедевр',
#      'slug': 'shedevr',
#      'language': 'rus',
#      'games_count': 1058,
#      'image_background': 'https://media.rawg.io/media/games/618/618c2031a07bbff6b4f611f10b6bcdbc.jpg'},
#     {'id': 42441,
#      'name': 'От третьего лица',
#      'slug': 'ot-tretego-litsa',
#      'language': 'rus',
#      'games_count': 1444,
#      'image_background': 'https://media.rawg.io/media/games/7ac/7aca7ccf0e70cd0974cb899ab9e5158e.jpg'},
#     {'id': 42442,
#      'name': 'Открытый мир',
#      'slug': 'otkrytyi-mir',
#      'language': 'rus',
#      'games_count': 2236,
#      'image_background': 'https://media.rawg.io/media/games/7cf/7cfc9220b401b7a300e409e539c9afd5.jpg'},
#     {'id': 42477,
#      'name': 'Мрачная',
#      'slug': 'mrachnaia',
#      'language': 'rus',
#      'games_count': 1103,
#      'image_background': 'https://media.rawg.io/media/games/b72/b7233d5d5b1e75e86bb860ccc7aeca85.jpg'},
#     {'id': 42478,
#      'name': 'Магия',
#      'slug': 'magiia',
#      'language': 'rus',
#      'games_count': 568,
#      'image_background': 'https://media.rawg.io/media/games/0bb/0bbceedd3e1420df0fdaf66a2e373b2b.jpg'},
#     {'id': 42480,
#      'name': 'Фэнтези',
#      'slug': 'fentezi',
#      'language': 'rus',
#      'games_count': 2702,
#      'image_background': 'https://media.rawg.io/media/games/d4b/d4bcd78873edd9992d93aff9cc8db0c8.jpg'},
#     {'id': 42489,
#      'name': 'Ролевой экшен',
#      'slug': 'rolevoi-ekshen',
#      'language': 'rus',
#      'games_count': 769,
#      'image_background': 'https://media.rawg.io/media/games/83f/83f6f70a7c1b86cd2637b029d8b42caa.jpg'},
#     {'id': 42506,
#      'name': 'Тёмное фэнтези',
#      'slug': 'tiomnoe-fentezi',
#      'language': 'rus',
#      'games_count': 551,
#      'image_background': 'https://media.rawg.io/media/games/934/934db575e66d63f2a6e86a2c688c141b.jpeg'},
#     {'id': 42508,
#      'name': 'Нелинейность',
#      'slug': 'nelineinost',
#      'language': 'rus',
#      'games_count': 710,
#      'image_background': 'https://media.rawg.io/media/games/ffe/ffed87105b14f5beff72ff44a7793fd5.jpg'},
#     {'id': 42529,
#      'name': 'Для взрослых',
#      'slug': 'dlia-vzroslykh',
#      'language': 'rus',
#      'games_count': 627,
#      'image_background': 'https://media.rawg.io/media/games/bd7/bd7cfccfececba1ec2b97a120a40373f.jpg'}],
#    'user_game': None,
#    'reviews_count': 3934,
#    'saturated_color': '0f0f0f',
#    'dominant_color': '0f0f0f',
#    'short_screenshots': [{'id': -1,
#      'image': 'https://media.rawg.io/media/games/618/618c2031a07bbff6b4f611f10b6bcdbc.jpg'},
#     {'id': 30336,
#      'image': 'https://media.rawg.io/media/screenshots/1ac/1ac19f31974314855ad7be266adeb500.jpg'},
#     {'id': 30337,
#      'image': 'https://media.rawg.io/media/screenshots/6a0/6a08afca95261a2fe221ea9e01d28762.jpg'},
#     {'id': 30338,
#      'image': 'https://media.rawg.io/media/screenshots/cdd/cdd31b6b4a687425a87b5ce231ac89d7.jpg'},
#     {'id': 30339,
#      'image': 'https://media.rawg.io/media/screenshots/862/862397b153221a625922d3bb66337834.jpg'},
#     {'id': 30340,
#      'image': 'https://media.rawg.io/media/screenshots/166/166787c442a45f52f4f230c33fd7d605.jpg'},
#     {'id': 30342,
#      'image': 'https://media.rawg.io/media/screenshots/f63/f6373ee614046d81503d63f167181803.jpg'}],
#    'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#     {'platform': {'id': 2, 'name': 'PlayStation', 'slug': 'playstation'}},
#     {'platform': {'id': 3, 'name': 'Xbox', 'slug': 'xbox'}},
#     {'platform': {'id': 7, 'name': 'Nintendo', 'slug': 'nintendo'}}],
#    'genres': [{'id': 3, 'name': 'Adventure', 'slug': 'adventure'},
#     {'id': 4, 'name': 'Action', 'slug': 'action'},
#     {'id': 5, 'name': 'RPG', 'slug': 'role-playing-games-rpg'}]}],
#  'user_platforms': False}

# %%
# check the key and values in json data
for val in rating_data.items():
    print(val)
# Out:
# ('count', 438710)
# ('next', 'https://api.rawg.io/api/games?dates=2000-01-01%2C2021-12-31&ordering=-rating&page=2')
# ('previous', None)
# ('results', [{'slug': 'the-world-ends-with-you-solo-remix-for-ipad', 'name': 'The World Ends with You: Solo Remix', 'playtime': 0, 'platforms': [{'platform': {'id': 3, 'name': 'iOS', 'slug': 'ios'}}], 'stores': [{'store': {'id': 4, 'name': 'App Store', 'slug': 'apple-appstore'}}], 'released': '2012-08-27', 'tba': False, 'background_image': 'https://media.rawg.io/media/screenshots/ebb/ebb68b67bb3c0fbd7f67b3ac56f9d24b.jpg', 'rating': 4.86, 'rating_top': 5, 'ratings': [{'id': 5, 'title': 'exceptional', 'count': 6, 'percent': 85.71}, {'id': 4, 'title': 'recommended', 'count': 1, 'percent': 14.29}], 'ratings_count': 7, 'reviews_text_count': 0, 'added': 12, 'added_by_status': {'yet': 2, 'owned': 3, 'beaten': 3, 'toplay': 3, 'dropped': 1}, 'metacritic': None, 'suggestions_count': 245, 'id': 132, 'score': None, 'clip': None, 'tags': [{'id': 117, 'name': 'Mystery', 'slug': 'mystery', 'language': 'eng', 'games_count': 5645, 'image_background': 'https://media.rawg.io/media/games/813/813f9dab418a3d549f8b9ad8ef2f3d9c.jpg'}, {'id': 24, 'name': 'RPG', 'slug': 'rpg', 'language': 'eng', 'games_count': 10453, 'image_background': 'https://media.rawg.io/media/games/c6b/c6bfece1daf8d06bc0a60632ac78e5bf.jpg'}, {'id': 295, 'name': 'Soundtrack', 'slug': 'soundtrack', 'language': 'eng', 'games_count': 1899, 'image_background': 'https://media.rawg.io/media/screenshots/5ce/5ce17393fdcd1a4356187e388fa21723.jpeg'}, {'id': 406, 'name': 'Story', 'slug': 'story', 'language': 'eng', 'games_count': 7485, 'image_background': 'https://media.rawg.io/media/screenshots/7f8/7f8b58994fc420fefaa5fb9992335a11.jpg'}, {'id': 604, 'name': 'simple', 'slug': 'simple', 'language': 'eng', 'games_count': 5292, 'image_background': 'https://media.rawg.io/media/screenshots/343/343ba814ff5e9bae8f67e7db4844f46d.jpg'}, {'id': 981, 'name': 'battle', 'slug': 'battle', 'language': 'eng', 'games_count': 8164, 'image_background': 'https://media.rawg.io/media/games/cd2/cd2a1a360839002bceadc5a8b3c7dbf7.jpg'}, {'id': 974, 'name': 'death', 'slug': 'death', 'language': 'eng', 'games_count': 2509, 'image_background': 'https://media.rawg.io/media/screenshots/548/5480f9bb1204045c5164d3f1293c9f41.jpg'}, {'id': 1129, 'name': 'art', 'slug': 'art', 'language': 'eng', 'games_count': 5503, 'image_background': 'https://media.rawg.io/media/screenshots/741/741bcfe15b1fe83ddc54be4f78749cc3.jpg'}, {'id': 1465, 'name': 'combat', 'slug': 'combat', 'language': 'eng', 'games_count': 3928, 'image_background': 'https://media.rawg.io/media/games/260/26023c855f1769a93411d6a7ea084632.jpeg'}, {'id': 1530, 'name': 'animation', 'slug': 'animation', 'language': 'eng', 'games_count': 2057, 'image_background': 'https://media.rawg.io/media/screenshots/9bf/9bf17af55dba0e49bb9259f62dafd6bc.jpg'}, {'id': 1724, 'name': 'Superpowers', 'slug': 'superpowers', 'language': 'eng', 'games_count': 322, 'image_background': 'https://media.rawg.io/media/screenshots/b3c/b3c672e0d9094baf91ef619002bbe82b.jpg'}, {'id': 1986, 'name': 'ice', 'slug': 'ice', 'language': 'eng', 'games_count': 1716, 'image_background': 'https://media.rawg.io/media/games/773/7731c87e1b3350634b1924a46f2da282.png'}], 'user_game': None, 'reviews_count': 7, 'saturated_color': '0f0f0f', 'dominant_color': '0f0f0f', 'short_screenshots': [{'id': -1, 'image': 'https://media.rawg.io/media/screenshots/ebb/ebb68b67bb3c0fbd7f67b3ac56f9d24b.jpg'}, {'id': 2039382, 'image': 'https://media.rawg.io/media/screenshots/323/3230d5c737b4378222b8b1d7388957e5.jpg'}, {'id': 2039383, 'image': 'https://media.rawg.io/media/screenshots/c69/c69a7b875d079473dcab1af6b03461bd.jpg'}, {'id': 2039384, 'image': 'https://media.rawg.io/media/screenshots/b3b/b3bdf18ce325a1ba7e7173abc8ac5b8b.jpg'}, {'id': 2039385, 'image': 'https://media.rawg.io/media/screenshots/980/9803e97dc9167666e781508137865232.jpg'}, {'id': 2039386, 'image': 'https://media.rawg.io/media/screenshots/3d3/3d350e051ece0015344dc779073ecc4f.jpg'}, {'id': 970, 'image': 'https://media.rawg.io/media/screenshots/047/047837d9aea61bca11fd389c9f ...
# ('user_platforms', False)

# %%
# create an empty list
list_columns = []

# %%
# 
for results in rating_data['results']:
    list_rows = []
    list_rows.append(results['id'])
    list_rows.append(results['name'])
    list_rows.append(results['released'])
    list_rows.append(results['rating'])
    console_list = []
    for platforms in results['platforms']:
        for k,v in platforms['platform'].items():
            if k=='name':
                console_list.append(v)
    list_rows.append(console_list)
    list_columns.append(list_rows)

# %%
# convert the embedded list into a data frame
df = pd.DataFrame(list_columns, columns = ['ID','Title','Release_Date','Rating','Console_Game'])

# %%
# check the data frame
df
# Out:
#         ID                                          Title Release_Date  \
# 0      132            The World Ends with You: Solo Remix   2012-08-27
# 1    53135                        Astro Boy: Omega Factor   2003-12-18
# 2   257281                                  Kara no Shojo   2018-10-22
# 3   339958                                Persona 5 Royal   2020-03-31
# 4   392459                  Shovel Knight: Shovel of Hope   2014-06-26
# 5   257255                The Witcher 3: Game of the Year   2016-08-30
# 6    58118                       Mafia II: Director’s Cut   2011-12-01
# 7     4167                            Mass Effect Trilogy   2012-11-06
# 8    43252      The Witcher 3: Wild Hunt - Blood and Wine   2016-05-30
# 9    43050     The Witcher 3: Wild Hunt - Hearts of Stone   2015-10-13
# 10    1111  METAL GEAR SOLID V: THE DEFINITIVE EXPERIENCE   2016-10-11
# 11  385406                Dark Souls III: The Ringed City   2017-03-28
# 12  378578          Grand Theft Auto IV: Complete Edition   2010-10-27
# 13   41478                              The Dream Machine   2010-12-14
# 14   27612          Harvest Moon: Friends of Mineral Town   2015-06-11
# 15  428561      Your Turn To Die : Death game by Majority   2017-08-28
# 16    1279                     Cataclysm: Dark Days Ahead   2015-12-09
# 17  364809                                      Tsukihime   2000-12-18
# 18    3636                      The Last Of Us Remastered   2014-07-29
# 19    3328                       The Witcher 3: Wild Hunt   2015-05-18
#
#     Rating                                       Console_Game
# 0     4.86                                              [iOS]
# 1     4.83                                 [Game Boy Advance]
# 2     4.83                                               [PC]
# 3     4.81                                    [PlayStation 4]
# 4     4.78  [PC, PlayStation 4, Xbox One, Nintendo Switch,...
# 5     4.77     [PC, Xbox One, PlayStation 4, Nintendo Switch]
# 6     4.77               [PC, macOS, Xbox 360, PlayStation 3]
# 7     4.75                                [PC, PlayStation 3]
# 8     4.75                      [PC, Xbox One, PlayStation 4]
# 9     4.74                      [PC, Xbox One, PlayStation 4]
# 10    4.74                      [PC, Xbox One, PlayStation 4]
# 11    4.74                      [PC, Xbox One, PlayStation 4]
# 12    4.71                      [PC, Xbox 360, PlayStation 3]
# 13    4.71                                        [PC, macOS]
# 14    4.71                                            [Wii U]
# 15    4.71                                               [PC]
# 16    4.71                          [PC, iOS, Android, Linux]
# 17    4.71                                               [PC]
# 18    4.70                                    [PlayStation 4]
# 19    4.68     [PC, Xbox One, PlayStation 4, Nintendo Switch]

# %%
# stack the Console_Game column, removing the list within the column
s = df.apply(lambda x: pd.Series(x['Console_Game']), axis=1).stack().reset_index(level = 1, drop=True)

# %%
# give your the stack data a column name
s.name = 'Console_Game'

# %%
# createa new data frame by dropping the Console_Game from the first data frame
df2 = df.drop('Console_Game',axis=1).join(s)

# %%
df2['Console_Game'] = pd.Series(df2['Console_Game'], dtype='object')

# %%
df2.dtypes
# Out:
# ID                int64
# Title            object
# Release_Date     object
# Rating          float64
# Console_Game     object
# dtype: object

# %%
# convert release_date column to datetime type
df2['Release_Date'] = pd.to_datetime(df2['Release_Date'])

# %%
df2.dtypes
# Out:
# ID                       int64
# Title                   object
# Release_Date    datetime64[ns]
# Rating                 float64
# Console_Game            object
# dtype: object

# %%
# export file as csv format
df2.to_csv('RawGamesAPI.csv', index = False)
